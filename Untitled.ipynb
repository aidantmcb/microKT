# %%
import numpy as np

import astropy.units as u  
import astropy.constants as c
from astropy.coordinates import SkyCoord

import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
import matplotlib 

from astropy.io import fits
from astropy.table import Table, join
from astropy.wcs import WCS
from scipy.interpolate import interp1d
from scipy.optimize import curve_fit
from scipy.stats import spearmanr

import pickle 
import sys
import os
import tqdm
import datetime

import emcee
import corner

import h5py
import multiprocessing as mp

# %%
from specfns import get_wavs, resample_interp, dopplershift, lambda0, sigma0
from filehandling import get_ca_res, get_madgics_res, get_medres
from spacefns_v2 import select_stars, find_nearest, find_radius, differentialAmplitude
from MCMCfns import logprob_2
# from sightline import Sightline
import time
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /scratch/local/u1371365/996976/ipykernel_373080/3879621885.py in <cell line: 3>()
#       1 from specfns import get_wavs, resample_interp, dopplershift, lambda0, sigma0
#       2 from filehandling import get_ca_res, get_madgics_res, get_medres
# ----> 3 from spacefns_v2 import select_stars, find_nearest, find_radius, differentialAmplitude
#       4 from MCMCfns import logprob_2
#       5 # from sightline import Sightline
#
# ~/nanoKT_v1/spacefns_v2.py in <module>
#       4
#       5 dustdata_class = globalvars.DustData
# ----> 6 dustdata = dustdata_class()
#       7
#       8
#
# ~/nanoKT_v1/globalvars.py in __init__(self, **kwargs)
#      37 class DustData:
#      38     def __init__(self, **kwargs):
# ---> 39         self.dustmap_grid(**kwargs)
#      40         # self.load_map()
#      41
#
# ~/nanoKT_v1/globalvars.py in dustmap_grid(self)
#      46         self.b_ = np.linspace(self.b0 - 9., self.b0 + 9., 800)
#      47         self.l, self.b, self.d = np.meshgrid(self.l_, self.b_, self.distance)
# ---> 48         self.coords = SkyCoord(self.l*u.deg, self.b*u.deg,
#      49                   distance=self.distance*u.pc, frame='galactic')
#      50     def load_map(self, map_fname = '/uufs/astro.utah.edu/common/home/u1371365/DIB_KT_CACloud/edenhofer_out.h5', **kwargs):
#
# ~/.local/lib/python3.10/site-packages/astropy/coordinates/sky_coordinate.py in __init__(self, copy, *args, **kwargs)
#     354             # Finally make the internal coordinate object.
#     355             frame_kwargs.update(components)
# --> 356             self._sky_coord_frame = frame_cls(copy=copy, **frame_kwargs)
#     357
#     358             if not self._sky_coord_frame.has_data:
#
# ~/.local/lib/python3.10/site-packages/astropy/coordinates/baseframe.py in __init__(self, copy, representation_type, differential_type, *args, **kwargs)
#     308             representation_type, differential_type
#     309         )
# --> 310         data = self._infer_data(args, copy, kwargs)  # possibly None.
#     311
#     312         shapes = [] if data is None else [data.shape]
#
# ~/.local/lib/python3.10/site-packages/astropy/coordinates/baseframe.py in _infer_data(self, args, copy, kwargs)
#     454
#     455                 try:
# --> 456                     representation_data = representation_cls(copy=copy, **repr_kwargs)
#     457                 except TypeError as e:
#     458                     # this except clause is here to make the names of the
#
# ~/.local/lib/python3.10/site-packages/astropy/coordinates/representation/spherical.py in __init__(self, lon, lat, distance, differentials, copy)
#     441
#     442     def __init__(self, lon, lat=None, distance=None, differentials=None, copy=True):
# --> 443         super().__init__(lon, lat, distance, copy=copy, differentials=differentials)
#     444         if (
#     445             not isinstance(self._distance, Distance)
#
# ~/.local/lib/python3.10/site-packages/astropy/coordinates/representation/base.py in __init__(self, differentials, *args, **kwargs)
#     670     def __init__(self, *args, differentials=None, **kwargs):
#     671         # Handle any differentials passed in.
# --> 672         super().__init__(*args, **kwargs)
#     673         if differentials is None and args and isinstance(args[0], self.__class__):
#     674             differentials = args[0]._differentials
#
# ~/.local/lib/python3.10/site-packages/astropy/coordinates/representation/base.py in __init__(self, *args, **kwargs)
#     212
#     213         # Pass attributes through the required initializing classes.
# --> 214         attrs = [
#     215             self.attr_classes[component](attr, copy=copy, subok=True)
#     216             for component, attr in zip(components, attrs)
#
# ~/.local/lib/python3.10/site-packages/astropy/coordinates/representation/base.py in <listcomp>(.0)
#     213         # Pass attributes through the required initializing classes.
#     214         attrs = [
# --> 215             self.attr_classes[component](attr, copy=copy, subok=True)
#     216             for component, attr in zip(components, attrs)
#     217         ]
#
# ~/.local/lib/python3.10/site-packages/astropy/coordinates/angles/core.py in __new__(cls, angle, unit, wrap_angle, **kwargs)
#     707         if wrap_angle is None:
#     708             wrap_angle = getattr(angle, "wrap_angle", self._default_wrap_angle)
# --> 709         self.wrap_angle = wrap_angle  # angle-like b/c property setter
#     710         return self
#     711
#
# ~/.local/lib/python3.10/site-packages/astropy/coordinates/angles/core.py in wrap_angle(self, value)
#     724     def wrap_angle(self, value):
#     725         self._wrap_angle = Angle(value, copy=False)
# --> 726         self._wrap_at(self.wrap_angle)
#     727
#     728     def __array_finalize__(self, obj):
#
# ~/.local/lib/python3.10/site-packages/astropy/coordinates/angles/core.py in _wrap_at(self, wrap_angle)
#     408         #
#     409         # Catch any invalid warnings from the floor division.
# --> 410         with np.errstate(invalid="ignore"):
#     411             wraps = (self_angle - wrap_angle_floor) // a360
#     412         valid = np.isfinite(wraps) & (wraps != 0)
#
# ~/.local/lib/python3.10/site-packages/numpy/core/_ufunc_config.py in __exit__(self, *exc_info)
#     433             self.oldcall = seterrcall(self.call)
#     434
# --> 435     def __exit__(self, *exc_info):
#     436         seterr(**self.oldstate)
#     437         if self.call is not _Unspecified:
#
# KeyboardInterrupt:
